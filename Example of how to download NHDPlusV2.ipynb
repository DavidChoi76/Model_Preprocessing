# %%
import NHDPlus_Extractor
from IPython.display import display
from PIL import Image

# %%
# set working directory
path = '/media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Example_1/'

# %%
# Display NHDPlusV2 Data Map
NHDPlusV2_path = "/media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Picture/v2webmap-pi.png"
display(Image.open(NHDPlusV2_path))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=900x682 at 0x7F3C52462780>

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
import PIL
# %matplotlib inline

# %%
# figure size in inches optional
rcParams['figure.figsize'] = 10,8
# read images
pic_name = ['vpu01.png', 'vpu02.png', 'vpu03n.png', 'vpu03s.png', 'vpu03w.png', 'vpu04.png', 'vpu05.png', 'vpu06.png', 
            'vpu07.png', 'vpu08.png', 'vpu09.png', 'vpu10u.png', 'vpu10l.png', 'vpu11.png', 'vpu12.png', 'vpu13.png', 
            'vpu14.png', 'vpu15.png', 'vpu16.png', 'vpu17.png', 'vpu18.png', 'vpu20.png', 'vpu21.png', '22a.png', 
            '22b.png', '22c.png']
pic_path_all =[]
for pic in pic_name:
    pic_path = "/media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Picture/" + pic
    pic_path_all.append(pic_path)

# %%
# Display Raster Processing Unit (RPUs) in 01 Northeast, 02 Mid Atlantic, 03N South Atlantic North
for num, pic in enumerate(pic_path_all[0:3]):
    rcParams['figure.figsize'] = 25,17
    img = PIL.Image.open(pic)
    plt.subplot(1, 3, num+1)
    plt.imshow(img)

# %%
# Display Raster Processing Unit (RPUs) in 03S South Atlantic South, 03W South Atlantic West, 04 Great Lakes
for num, pic in enumerate(pic_path_all[3:6]):
    rcParams['figure.figsize'] = 25,17
    img = PIL.Image.open(pic)
    plt.subplot(1, 3, num+1)
    plt.imshow(img)

# %%
# Display Raster Processing Unit (RPUs) in 05 Ohio, 06 Tennessee, 07 Upper Mississippi
for num, pic in enumerate(pic_path_all[6:9]):
    rcParams['figure.figsize'] = 25,17
    img = PIL.Image.open(pic)
    plt.subplot(1, 3, num+1)
    plt.imshow(img)

# %%
# Display Raster Processing Unit (RPUs) in 08 Lower Mississippi, 09 Souris-Red-Rainy, 10U Upper Missouri
for num, pic in enumerate(pic_path_all[9:12]):
    rcParams['figure.figsize'] = 25,17
    img = PIL.Image.open(pic)
    plt.subplot(1, 3, num+1)
    plt.imshow(img)

# %%
# Display Raster Processing Unit (RPUs) in 10L Lower Missouri, 11 Ark-Red-White, 12 Texas
for num, pic in enumerate(pic_path_all[12:15]):
    rcParams['figure.figsize'] = 25,17
    img = PIL.Image.open(pic)
    plt.subplot(1, 3, num+1)
    plt.imshow(img)

# %%
# Display Raster Processing Unit (RPUs) in 13 Rio Grande, 14 Upper Colorado, 15 Lower Colorado
for num, pic in enumerate(pic_path_all[15:18]):
    rcParams['figure.figsize'] = 25,17
    img = PIL.Image.open(pic)
    plt.subplot(1, 3, num+1)
    plt.imshow(img)

# %%
# Display Raster Processing Unit (RPUs) in 16 Great Basin, 17 Pacific Northwest, 18 California
for num, pic in enumerate(pic_path_all[18:21]):
    rcParams['figure.figsize'] = 25,17
    img = PIL.Image.open(pic)
    plt.subplot(1, 3, num+1)
    plt.imshow(img)

# %%
# Display Raster Processing Unit (RPUs) in 20 Hawaii, 21 Puerto Rico/U.S. Virgin Islands, 22A American Samoa
for num, pic in enumerate(pic_path_all[21:24]):
    rcParams['figure.figsize'] = 25,17
    img = PIL.Image.open(pic)
    plt.subplot(1, 3, num+1)
    plt.imshow(img)

# %%
# Display Raster Processing Unit (RPUs) in 22G Guam, 22M Northern Mariana Islands
for num, pic in enumerate(pic_path_all[24:27]):
    rcParams['figure.figsize'] = 25,17
    img = PIL.Image.open(pic)
    plt.subplot(1, 3, num+1)
    plt.imshow(img)

# %% [markdown]
# ### Set NHDPlusV2 object to download and manipulate NHDPlusV2

# %%
# set NHDPlusV2 object to download and manipulate NHDPlusV2
NHDPlusV2 = NHDPlus_Extractor.NHDPlusExtractor(path)

# %% [markdown]
# ### Table of NHDPlusV2 Area according to Name, VPUs, and RPUs

# %% [markdown]
# | List of Area |	Vector Processing Units (VPUs)	|	Raster Processing Units (RPUs)|
# |:---:|:-----------------------------------:|:--------------------------------:|
# |01 Northeast	|	01	|	01a|
# |02 Mid Atlantic	|	02	|	02a, 02b|
# |03N South Atlantic North	|	03N	|	03a, 03b|
# |03S South Atlantic South	|	03S	|	03c, 03d|
# |03W South Atlantic West	|	03W	|	03e, 03f|
# |04 Great Lakes	|	04	|	04a, 04b, 04c, 04d|
# |05 Ohio	|	05	|	05a, 05b, 05c, 05d|
# |06 Tennessee	|	06	|	06a|
# |07 Upper Mississippi	|	07	|	07a, 07b, 07c|
# |08 Lower Mississippi	|	08	|	08a, 08b, 03g|
# |09 Souris-Red-Rainy	|	09	|	09a|
# |10L Lower Missouri	|	10L	|	10a, 10b, 10c, 10d|
# |10U Upper Missouri	|	10U	|	10e, 10f, 10g, 10h, 10i|
# |11 Ark-Red-White	|	11	|	11a, 11b, 11c, 11d|
# |12 Texas	|	12	|	12a, 12b, 12c, 12d|
# |13 Rio Grande	|	13	|	13a, 13b, 13c, 13d|
# |14 Upper Colorado	|	14	|	14a, 14b|
# |15 Lower Colorado	|	15	|	15a, 15b|
# |16 Great Basin	|	16	|	16a, 16b|
# |17 Pacific Northwest	|	17	|	17a, 17b, 17c, 17d|
# |18 California	|	18	|	18a, 18b, 18c|
# |20 Hawaii	|	20	|	20a, 20b, 20c, 20d, 20e, 20f, 20g, 20h|
# |21 Puerto Rico/U.S. Virgin Islands	|	21	|	21a, 21b, 21c|
# |22A American Samoa	|	22AS	|	22c|
# |22G Guam	|	22GU	|	22a|
# |22M Northern Mariana Islands	|	22MP	|	22b|

# %%
# Vertor Components name
Vector = NHDPlusV2.VPU_Files
Vector
# Out:
# ['EROMExtension',
#  'NHDPlusAttributes',
#  'NHDPlusBurnComponents',
#  'NHDPlusCatchment',
#  'NHDSnapshot',
#  'VPUAttributeExtension',
#  'VogelExtension',
#  'WBDSnapshot',
#  'NHDSnapshotFGDB']

# %%
# find Vector Processing Unit (VPU) according to the specific VPU
for vector in Vector:
    NHDPlusV2.gather_vpu_links(vpu_input='01', filename_input = vector)
# Out:
# FOUND https://s3.amazonaws.com/nhdplus/NHDPlusV21/Data/NHDPlusNE/NHDPlusV21_NE_01_EROMExtension_06.7z
# FOUND https://s3.amazonaws.com/nhdplus/NHDPlusV21/Data/NHDPlusNE/NHDPlusV21_NE_01_NHDPlusAttributes_09.7z
# FOUND https://s3.amazonaws.com/nhdplus/NHDPlusV21/Data/NHDPlusNE/NHDPlusV21_NE_01_NHDPlusBurnComponents_02.7z
# FOUND https://s3.amazonaws.com/nhdplus/NHDPlusV21/Data/NHDPlusNE/NHDPlusV21_NE_01_NHDPlusCatchment_01.7z
# FOUND https://s3.amazonaws.com/nhdplus/NHDPlusV21/Data/NHDPlusNE/NHDPlusV21_NE_01_NHDSnapshot_04.7z
# FOUND https://s3.amazonaws.com/nhdplus/NHDPlusV21/Data/NHDPlusNE/NHDPlusV21_NE_01_VPUAttributeExtension_05.7z
# FOUND https://s3.amazonaws.com/nhdplus/NHDPlusV21/Data/NHDPlusNE/NHDPlusV21_NE_01_VogelExtension_01.7z
# FOUND https://s3.amazonaws.com/nhdplus/NHDPlusV21/Data/NHDPlusNE/NHDPlusV21_NE_01_WBDSnapshot_03.7z
# FOUND https://s3.amazonaws.com/nhdplus/NHDPlusV21/Data/NHDPlusNE/NHDPlusV21_NE_01_NHDSnapshotFGDB_04.7z

# %%
# find RPU from VPU
NHDPlusV2.VPU_to_RPU['01']
# Out:
# ['01a']

# %%
# Raster Components name
Raster = NHDPlusV2.RPU_Files
Raster
# Out:
# ['CatSeed',
#  'FdrFac',
#  'FdrNull',
#  'FilledAreas',
#  'Hydrodem',
#  'NEDSnapshot',
#  'HydroDem',
#  'Catseed']

# %%
# find Raster Processing Unit (RPU) according to the specific RPU
for raster in Raster:
    NHDPlusV2.gather_rpu_links(rpu_input='01a', filename_input = raster)
# Out:
# FOUND https://s3.amazonaws.com/nhdplus/NHDPlusV21/Data/NHDPlusNE/NHDPlusV21_NE_01_01a_CatSeed_01.7z
# FOUND https://s3.amazonaws.com/nhdplus/NHDPlusV21/Data/NHDPlusNE/NHDPlusV21_NE_01_01a_FdrFac_01.7z
# FOUND https://s3.amazonaws.com/nhdplus/NHDPlusV21/Data/NHDPlusNE/NHDPlusV21_NE_01_01a_FdrNull_01.7z
# FOUND https://s3.amazonaws.com/nhdplus/NHDPlusV21/Data/NHDPlusNE/NHDPlusV21_NE_01_01a_FilledAreas_01.7z
# FOUND https://s3.amazonaws.com/nhdplus/NHDPlusV21/Data/NHDPlusNE/NHDPlusV21_NE_01_01a_Hydrodem_01.7z
# FOUND https://s3.amazonaws.com/nhdplus/NHDPlusV21/Data/NHDPlusNE/NHDPlusV21_NE_01_01a_NEDSnapshot_01.7z
# no link found for  https://s3.amazonaws.com/nhdplus/NHDPlusV21/Data/NHDPlusNE/NHDPlusV21_NE_01_01a_HydroDem_25.7z
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-8-78421ee708d0> in <module>
# ...

# %%
# Raster Processing Unit (RPU) according to the specific rpu and component name
NHDPlusV2.gather_rpu_links(rpu_input='01a', filename_input='CatSeed')
# Out:
# FOUND https://s3.amazonaws.com/nhdplus/NHDPlusV21/Data/NHDPlusNE/NHDPlusV21_NE_01_01a_CatSeed_01.7z
# 'https://s3.amazonaws.com/nhdplus/NHDPlusV21/Data/NHDPlusNE/NHDPlusV21_NE_01_01a_CatSeed_01.7z'

# %%
NHDPlusV2.getvpufile(vpu='01', filename='NHDPlusCatchment')
# Out:
# the link to your selected vpu and filename is https://s3.amazonaws.com/nhdplus/NHDPlusV21/Data/NHDPlusNE/NHDPlusV21_NE_01_NHDPlusCatchment_01.7z
# 'https://s3.amazonaws.com/nhdplus/NHDPlusV21/Data/NHDPlusNE/NHDPlusV21_NE_01_NHDPlusCatchment_01.7z'

# %%
NHDPlusV2.download_decompress(vpu='01', filename='NHDPlusCatchment')
# Out:
# the link to your selected vpu and filename is https://s3.amazonaws.com/nhdplus/NHDPlusV21/Data/NHDPlusNE/NHDPlusV21_NE_01_NHDPlusCatchment_01.7z
# finished downloading file for vpu:01, filename:NHDPlusV21_NE_01_NHDPlusCatchment_01.7z
# /media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Example_1/Example of how to download NHDPlusV2.ipynb decompressed
# /media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Example_1/link.txt decompressed
# /media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Example_1/NHDPlusV21_NE_01_NHDPlusCatchment_01.7z decompressed
# /media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Example_1/.ipynb_checkpoints/Example of how to download NHDPlusV2-checkpoint.ipynb decompressed

# %%
NHDPlusV2.download_decompress(rpu='01a', filename='Hydrodem')
# Out:
# the link to your selected rpu and filename is https://s3.amazonaws.com/nhdplus/NHDPlusV21/Data/NHDPlusNE/NHDPlusV21_NE_01_01a_Hydrodem_01.7z
# finished downloading file for rpu:01a, filename:NHDPlusV21_NE_01_01a_Hydrodem_01.7z
# /media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Example_1/Example of how to download NHDPlusV2.ipynb decompressed
# /media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Example_1/link.txt decompressed
# /media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Example_1/NHDPlusV21_NE_01_01a_Hydrodem_01.7z decompressed
# /media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Example_1/NHDPlusV21_NE_01_NHDPlusCatchment_01.7z decompressed
# /media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Example_1/.ipynb_checkpoints/Example of how to download NHDPlusV2-checkpoint.ipynb decompressed
# /media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Example_1/NHDPlusNE/NHDPlusV21_NE_01_01a_HydroDem_01.txt decompressed
# ...

# %%
NHDPlusV2.download_decompress(vpu='01', filename='NHDPlusAttributes')
# Out:
# the link to your selected vpu and filename is https://s3.amazonaws.com/nhdplus/NHDPlusV21/Data/NHDPlusNE/NHDPlusV21_NE_01_NHDPlusAttributes_09.7z
# finished downloading file for vpu:01, filename:NHDPlusV21_NE_01_NHDPlusAttributes_09.7z
# /media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Example_1/arc0002r~ decompressed
# /media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Example_1/Example of how to download NHDPlusV2.ipynb decompressed
# /media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Example_1/link.txt decompressed
# /media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Example_1/NHDPlusV21_NE_01_01a_Hydrodem_01.7z decompressed
# /media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Example_1/NHDPlusV21_NE_01_NHDPlusAttributes_09.7z decompressed
# /media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Example_1/NHDPlusV21_NE_01_NHDPlusCatchment_01.7z decompressed
# ...

# %%
NHDPlusV2.download_decompress(vpu='01', filename='NHDSnapshot')
# Out:
# the link to your selected vpu and filename is https://s3.amazonaws.com/nhdplus/NHDPlusV21/Data/NHDPlusNE/NHDPlusV21_NE_01_NHDSnapshot_04.7z
# finished downloading file for vpu:01, filename:NHDPlusV21_NE_01_NHDSnapshot_04.7z
# /media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Example_1/arc0002r~ decompressed
# /media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Example_1/Example of how to download NHDPlusV2.ipynb decompressed
# /media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Example_1/link.txt decompressed
# /media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Example_1/NHDPlusV21_NE_01_01a_Hydrodem_01.7z decompressed
# /media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Example_1/NHDPlusV21_NE_01_NHDPlusAttributes_09.7z decompressed
# /media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Example_1/NHDPlusV21_NE_01_NHDPlusCatchment_01.7z decompressed
# /media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Example_1/NHDPlusV21_NE_01_NHDSnapshot_04.7z decompressed
# ...

# %%
flowline_path = path + 'NHDPlusNE/NHDPlus01/NHDSnapshot/Hydrography/NHDFlowline'

# %%
comids = NHDPlusV2.get_comids(flowline_path)

# %%
read_dbf = flowline_path + '.dbf'
read_dbf
# Out:
# '/media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/Example_1/NHDPlusNE/NHDPlus01/NHDSnapshot/Hydrography/NHDFlowline.dbf'

# %%
NHDPlusV2.read_dbf(source = read_dbf, comids = comids, attributes = "GNIS_NAME")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-a270e959dec5> in <module>
# ----> 1 NHDPlusV2.read_dbf(source = read_dbf, comids = comids, attributes = "GNIS_NAME")
#
# /media/sf_pysumma/RHESSys/PyNHDPlus/NHDPlus_Extractor/NHDPlus_Extractor.py in read_dbf(self, source, comids, attributes, verbose)
#    1194                     print('the comid_index is ' + str(comid_index[0]))
#    1195
# -> 1196             index.append([pos for pos,j in enumerate(fields) if attribute[0] == j][0])
#    1197
#    1198         if verbose is True:
#
# IndexError: list index out of range

# %%
NHDPlusV2.get_comids(flowline_path)
# Out:
# [721640,
#  717072,
#  717076,
#  717082,
#  717084,
#  718990,
#  718994,
#  718998,
#  719002,
#  719006,
#  719010,
#  719014,
#  719018,
#  719032,
#  719034,
#  719036,
#  719038,
#  717916,
#  719024,
#  717912,
#  717914,
#  718766,
#  717884,
#  717874,
#  719050,
#  719052,
#  719056,
#  719060,
#  719066,
#  719068,
#  719076,
#  719082,
#  719086,
#  719090,
#  719100,
#  719106,
#  719110,
#  719116,
#  719126,
#  719122,
#  719130,
#  719132,
#  719136,
#  718134,
#  719138,
#  718100,
#  718076,
#  718068,
#  719140,
#  719162,
#  719168,
#  719172,
#  719188,
#  719190,
#  719192,
#  719202,
#  719208,
#  719462,
#  719230,
#  719232,
#  718926,
#  718284,
#  718920,
#  718274,
#  718340,
#  718364,
#  718382,
#  718390,
#  718392,
#  718394,
#  718934,
#  718472,
#  719354,
#  718466,
#  718944,
#  718942,
#  718484,
#  718558,
#  718560,
#  718592,
#  719944,
#  719962,
#  718546,
#  718554,
#  718564,
#  718568,
#  718576,
#  718588,
#  718608,
#  718630,
# ...
